# %% [markdown]
# **Possible TODO:**
# - Plot observations on a map using xy-coordinates
# - Build basic KNN and linear regression with numerical features only
# - Check assumptions, log transformation for price
# - Build basic logistic and SVM classification for 1M homes
# - Train test split and cross-validation
# - Scaling min-max or 0-1
# - Add categories with one-hot encoding
# - Add zip codes with one-hot encoding
# - Add L1/L2 and/or Elastic Net
# - Spark linear regression pipeline for cross-validation
# - Spark ensemble regression pipeline benchmarking against AutoML
# - Spark logistic and/or SVM classification pipeline for cross-validation
# - Check mis-classified homes
# - Add Four Squares local data
# - Repeat Spark classifications, all the models
# - Pull and plot important venues as factors
# - Most important features comments NLP sentiment analysis
# - Add 'great venue' vs 'not so good'
# - Repeat Spark best classification model

# %%
# Import pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Intro

# %%
# Read the restaurants csv file
restaurants = pd.read_csv("Paris/paris_restaurants.csv")
# Inspect the first rows of restaurants
print(restaurants.head())
# Out:
#                                  type              x             y
# 0                 European restuarant  259641.691646  6.251867e+06
# 1       Traditional French restaurant  259572.339603  6.252030e+06
# 2       Traditional French restaurant  259657.276374  6.252143e+06
# 3  Indian / Middle Eastern restaurant  259684.438330  6.252203e+06
# 4       Traditional French restaurant  259597.943086  6.252230e+06

# %%
# Make a plot of all points
fig, ax = plt.subplots()
ax.plot(restaurants.x, restaurants.y, 'o')
plt.show()

# %%
# Read the restaurants csv file
restaurants = pd.read_csv("Paris/paris_restaurants.csv")

# Import contextily
import contextily

# A figure of all restaurants with background
fig, ax = plt.subplots()
ax.plot(restaurants.x, restaurants.y, 'o', markersize=1)
contextily.add_basemap(ax)

plt.show()

# %% [markdown]
# # **GeoPandas**

# %%
!

# %%
# # Import GeoPandas
# import geopandas

# # Read the Paris districts dataset
# districts = geopandas.read_file('Paris/paris_districts.gpkg')

# # Inspect the first rows
# print(districts.head())

# # Make a quick visualization of the districts
# districts.plot()
# plt.show()

# %%
# # Check what kind of object districts is
# print(type(districts))

# # Check the type of the geometry attribute
# print(districts.geometry)

# # Inspect the first rows of the geometry
# print(districts.geometry.head())

# # Inspect the area of the districts
# print(districts.geometry.area)

# %%
# Read the restaurants csv file into a DataFrame
df = pd.read_csv("Paris/paris_restaurants.csv")

# Convert it to a GeoDataFrame
restaurants = geopandas.GeoDataFrame(df, geometry=geopandas.points_from_xy(df.x, df.y))

# Inspect the first rows of the restaurants GeoDataFrame
#print(restaurants.head())

# Make a plot of the restaurants
ax = restaurants.plot(markersize=1, figsize=(20, 10))
import contextily
contextily.add_basemap(ax)
plt.show()

# %%
df = pd.read_csv('../../demo/house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...
